# %% [markdown]
# # Resnet-50
#
# [ver detalles](https://huggingface.co/microsoft/resnet-50)

# %%
# !pip install transformers datasets -q

# %%
from transformers import AutoImageProcessor, ResNetForImageClassification
import torch
from datasets import load_dataset

# %% [markdown]
# # Load dataset

# %%
dataset = load_dataset("huggingface/cats-image")
image = dataset["test"]["image"][0]

# %%
dataset["test"]["image"][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F341A8D3C70>

# %% [markdown]
# # Load processor and model

# %%
processor = AutoImageProcessor.from_pretrained("microsoft/resnet-50")
model = ResNetForImageClassification.from_pretrained("microsoft/resnet-50")

# %% [markdown]
# # Preprocess image

# %%
inputs = processor(image, return_tensors="pt")

# %%
inputs["pixel_values"].shape
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# # Make predictions

# %%
import matplotlib.pyplot as plt

# %%
def plot(image, pred, ax=None, size=20):
  if ax == None:
    plt.imshow(image)
    plt.title(f"Prediction: {pred}", size=20)
    plt.xticks([])
    plt.yticks([])
    plt.show()
  else:
    ax.imshow(image)
    ax.set_title(f"Prediction: {pred}", size=size)
    ax.set_xticks([])
    ax.set_yticks([])

# %%
with torch.no_grad():
    output = model(**inputs)
    logits = output.logits

# %%
# model predicts one of the 1000 ImageNet classes
predicted_label = logits.argmax(-1).item()
pred = model.config.id2label[predicted_label]

plot(image, pred)

# %% [markdown]
# # Take a look at some of the Resnet-50 classes

# %%
list(model.config.label2id.keys())[:10]
# Out:
# ['Afghan hound, Afghan',
#  'African chameleon, Chamaeleo chamaeleon',
#  'African crocodile, Nile crocodile, Crocodylus niloticus',
#  'African elephant, Loxodonta africana',
#  'African grey, African gray, Psittacus erithacus',
#  'African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus',
#  'Airedale, Airedale terrier',
#  'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier',
#  'American alligator, Alligator mississipiensis',
#  'American black bear, black bear, Ursus americanus, Euarctos americanus']

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['image'],
#         num_rows: 1
#     })
# })

# %% [markdown]
# # Make more predictions

# %%
dataset2 = load_dataset("Bingsu/Cat_and_Dog")

# %%
def predict(image):
  inputs = processor(image, return_tensors="pt")
  with torch.no_grad():
      logits = model(**inputs).logits
  predicted_label = logits.argmax(-1).item()
  pred = model.config.id2label[predicted_label]
  return pred

# %%
fig = plt.figure(figsize=(10,10))
for i in range(1,10):
  ax = fig.add_subplot(3,3,i)
  image = dataset2["test"]["image"][i]
  pred = predict(image)
  plot(image, pred, ax=ax, size=10)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
for i in range(1,10):
  ax = fig.add_subplot(3,3,i)
  image = dataset2["test"]["image"][-i]
  pred = predict(image)
  plot(image, pred, ax=ax, size=10)
plt.show()
